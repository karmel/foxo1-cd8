# %% [markdown]
# '''
# There are many genes of interest with regard to the WT vs. KO phenotype.
#
# We compare here.
# '''

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context('poster')

# %%
filename = '../data/rpkm.txt'
data = pd.io.parsers.read_csv(filename, 
                                    sep='\t', 
                                    header=0)
data.columns
# Out:
# Index(['Transcript/RepeatID (cmd=analyzeRepeats.pl rna mm10 -strand both -count exons -d CD8TCell-KLRGhi-RNA-LCMV-12d-KAA-14-10-31 CD8TCell-KLRGhi-RNA-LCMV-7d-KAA-14-10-31 CD8TCell-KLRGlo-RNA-LCMV-12d-KAA-14-10-31 CD8TCell-KLRGlo-RNA-LCMV-7d-KAA-14-10-31 CD8TCell-RNA-LCMV-0d-KAA-14-10-31 CD8TCell-RNA-LCMV-35d-rep1-KAA-14-10-31 CD8TCell-RNA-LCMV-35d-rep2-KAA-14-10-31 Foxo1-KO-CD8TCell-KLRGhi-RNA-LCMV-12d-KAA-14-10-31 Foxo1-KO-CD8TCell-KLRGhi-RNA-LCMV-7d-KAA-14-10-31 Foxo1-KO-CD8TCell-KLRGlo-RNA-LCMV-7d-KAA-14-10-31 Foxo1-KO-CD8TCell-RNA-LCMV-0d-KAA-14-10-31 -rpkm -condenseGenes)', 'chr', 'start', 'end', 'strand', 'Length', 'Copies', 'Annotation/Divergence', 'CD8TCell-KLRGhi-RNA-LCMV-12d-KAA-14-10-31 reads FPKM', 'CD8TCell-KLRGhi-RNA-LCMV-7d-KAA-14-10-31 reads FPKM', 'CD8TCell-KLRGlo-RNA-LCMV-12d-KAA-14-10-31 reads FPKM', 'CD8TCell-KLRGlo-RNA-LCMV-7d-KAA-14-10-31 reads FPKM', 'CD8TCell-RNA-LCMV-0d-KAA-14-10-31 reads FPKM', 'CD8TCell-RNA-LCMV-35d-rep1-KAA-14-10-31 reads FPKM', 'CD8TCell-RNA-LCMV-35d-rep2-KAA-14-10-31 reads FPKM', 'Foxo1-KO-CD8TCell-KLRGhi-RNA-LCMV-12d-KAA-14-10-31 reads FPKM', 'Foxo1-KO-CD8TCell-KLRGhi-RNA-LCMV-7d-KAA-14-10-31 reads FPKM', 'Foxo1-KO-CD8TCell-KLRGlo-RNA-LCMV-7d-KAA-14-10-31 reads FPKM', 'Foxo1-KO-CD8TCell-RNA-LCMV-0d-KAA-14-10-31 reads FPKM'], dtype='object')

# %%
# Clean up column names for easier parsing.
new_index = []
for col in data.columns:
    cleaned = col.replace('-KAA-14-10-31 reads','').replace(' FPKM','')
    cleaned = cleaned.replace('CD8TCell-','').replace('RNA-','')
    new_index.append(cleaned)
new_index[0] = 'id'
data.columns = new_index
data.columns
# Out:
# Index(['id', 'chr', 'start', 'end', 'strand', 'Length', 'Copies', 'Annotation/Divergence', 'KLRGhi-LCMV-12d', 'KLRGhi-LCMV-7d', 'KLRGlo-LCMV-12d', 'KLRGlo-LCMV-7d', 'LCMV-0d', 'LCMV-35d-rep1', 'LCMV-35d-rep2', 'Foxo1-KO-KLRGhi-LCMV-12d', 'Foxo1-KO-KLRGhi-LCMV-7d', 'Foxo1-KO-KLRGlo-LCMV-7d', 'Foxo1-KO-LCMV-0d'], dtype='object')

# %%
# Extract the genes we care about.
factor_pairs = ((('Tcf7'),('NM_009331')),
           (('Eomes'),('NM_001164789')),
           (('Tbx21'),('NM_019507')),
           (('Bcl2'),('NM_009741')),
           (('Id2'),('NM_010496')),
           (('Id3'),('NM_008321')),
           (('Prdm1'),('NM_007548')),
           (('Ccl5'),('NM_013653')),
           (('Klrg1'),('NM_016970')),
           (('Bcl6'),('NM_009744')),
           (('Stat3'),('NM_011486')),
           (('Stat4'),('NM_011487')),
           (('Ccr7'),('NM_030693')),
           (('Il7r'),('NM_008372')),
           (('Nur77'),('NM_010444')),
           (('Nr4a2'),('NM_013613')),
           (('Klf4'),('NM_010637')),
           (('Coro2a'),('NM_001164804')),
           (('Ldlr'),('NM_010700')),
           (('Ly6c1'),('NM_001252055')),
           (('Ly6c2'),('NM_001099217')),
           (('Il18rap'),('NM_010553')),
           (('Ctla4'),('')),
           (('Cd55'),('')),
           )
zipped = list(zip(*factor_pairs))
factors = pd.DataFrame({'gene_name':zipped[0],
                        'id':zipped[1],})
factors
# Out:
#    gene_name            id
# 0       Tcf7     NM_009331
# 1      Eomes  NM_001164789
# 2      Tbx21     NM_019507
# 3       Bcl2     NM_009741
# 4        Id2     NM_010496
# 5        Id3     NM_008321
# 6      Prdm1     NM_007548
# 7       Ccl5     NM_013653
# 8      Klrg1     NM_016970
# 9       Bcl6     NM_009744
# 10     Stat3     NM_011486
# 11     Stat4     NM_011487
# 12      Ccr7     NM_030693
# 13      Il7r     NM_008372
# 14     Nur77     NM_010444
# 15     Nr4a2     NM_013613
# 16      Klf4     NM_010637
# 17    Coro2a  NM_001164804
# 18      Ldlr     NM_010700
# 19     Ly6c1  NM_001252055
# 20     Ly6c2  NM_001099217
# 21   Il18rap     NM_010553

# %%
subdata = pd.merge(factors, data, on='id', how='inner')
subdata.index = subdata['gene_name']
subdata
# Out:
#           gene_name            id    chr      start        end strand  Length  \
# gene_name
# Tcf7           Tcf7     NM_009331  chr11   52252604   52282571      -    2226
# Tbx21         Tbx21     NM_019507  chr11   97098007   97115331      -    2544
# Bcl2           Bcl2     NM_009741   chr1  106538178  106714290      -    7203
# Id2             Id2     NM_010496  chr12   25093799   25096092      -    1267
# Id3             Id3     NM_008321   chr4  136143822  136145392      +     948
# Prdm1         Prdm1     NM_007548  chr10   44437175   44458687      -    5134
# Ccl5           Ccl5     NM_013653  chr11   83525779   83530518      -     526
# Klrg1         Klrg1     NM_016970   chr6  122270597  122282833      -    1357
# Bcl6           Bcl6     NM_009744  chr16   23965052   23988612      -    3273
# Stat4         Stat4     NM_011487   chr1   52008244   52107184      +    2955
# Il7r           Il7r     NM_008372  chr15    9506159    9529876      -    3200
# Nur77         Nur77     NM_010444  chr15  101266846  101274794      +    2467
# Klf4           Klf4     NM_010637   chr4   55527137   55532475      -    3037
# Coro2a       Coro2a  NM_001164804   chr4   46536937   46601929      -    3874
# Ldlr           Ldlr     NM_010700   chr9   21723576   21749918      +    4513
# Ly6c2         Ly6c2  NM_001099217  chr15   75108161   75111949      -     795
# Il18rap     Il18rap     NM_010553   chr1   40515362   40551705      +    4874
#
#            Copies                              Annotation/Divergence  \
# gene_name
# Tcf7            1  Tcf7|AI465550|TCF-1|Tcf1|RP23-223A11.3|11 B1.3...
# Tbx21           1  Tbx21|TBT1|Tbet|Tblym|RP23-428N4.9|11|11 D|pro...
# Bcl2            1  Bcl2|AW986256|Bcl-2|C430015F12Rik|D630044D05Ri...
# Id2             1  Id2|AI255428|C78922|Idb2|bHLHb26|-|12 B|12 8.5...
# Id3             1  Id3|Hlh462|Idb3|bHLHb25|RP23-118A9.1|4 D3|4 68...
# Prdm1           1  Prdm1|Blimp-1|Blimp1|PRDI-BF1|ZNFPR1A1|b2b1765...
# Ccl5            1  Ccl5|MuRantes|RANTES|SISd|Scya5|TCP228|RP23-32...
# Klrg1           1  Klrg1|2F1-Ag|MAFA|MAFA-L|-|6 F1|6 57.52 cM|pro...
# Bcl6            1       Bcl6|Bcl5|-|16 B1|16 15.26 cM|protein-coding
# Stat4           1         Stat4|-|-|1 C1.1|1 26.67 cM|protein-coding
# Il7r            1  Il7r|CD127|IL-7Ralpha|-|15 A1|15 4.16 cM|prote...
# Nur77           1  Nr4a1|GFRP1|Gfrp|Hbr-1|Hbr1|Hmr|N10|NGFI-B|NGF...
# Klf4            1  Klf4|EZF|Gklf|Zie|RP23-322L22.2|4 B3|4 29.76 c...
# Coro2a          1  Coro2a|9030208C03Rik|AI563590|IR10|RP23-117B19...
# Ldlr            1        Ldlr|Hlb301|-|9 A3|9 7.87 cM|protein-coding
# Ly6c2           1     Ly6c2|Ly-6C.2|Ly-6C2|-|15 D3|15|protein-coding
# Il18rap         1  Il18rap|AcPL|IL-18R-beta|IL-18RAcP|IL-18Rbeta|...
#
#            KLRGhi-LCMV-12d  KLRGhi-LCMV-7d  KLRGlo-LCMV-12d  KLRGlo-LCMV-7d  \
# gene_name
# Tcf7               136.072          17.331          381.005         144.467
# Tbx21              239.716         168.476          121.415         128.535
# Bcl2                 5.895           5.579           35.990          12.018
# Id2                366.855         196.450          329.283         202.082
# Id3                  0.776           1.478            3.477           7.452
# Prdm1               16.071          17.365            5.650          11.841
# Ccl5             34903.381        9027.612        20190.829        7359.080
# Klrg1              408.354         369.941           16.130          38.211
# Bcl6                 6.955           1.675            6.244           2.385
# Stat4               61.042          66.378           61.556          70.353
# Il7r                38.477           4.701          244.310          18.085
# Nur77              151.320          67.947           77.902          71.364
# Klf4                 4.292           2.714           14.545           4.394
# Coro2a              11.108          25.353            9.922          19.925
# Ldlr                 0.643           5.279            1.023           5.044
# Ly6c2             1053.406        1024.020          850.614         816.697
# Il18rap            261.794         186.689           97.704         101.528
#
#            LCMV-0d  LCMV-35d-rep1  LCMV-35d-rep2  Foxo1-KO-KLRGhi-LCMV-12d  \
# gene_name
# Tcf7       754.695        449.765        459.327                    14.910
# Tbx21        1.323        100.808        110.058                   283.589
# Bcl2        20.921         52.124         48.917                     1.799
# Id2         38.352        320.101        295.259                   295.039
# Id3         55.764          4.888          4.178                     0.734
# Prdm1        0.034          5.251          5.267                    20.447
# Ccl5        61.942      15799.732      16951.940                 22804.126
# Klrg1        0.477         67.203         74.286                   460.762
# Bcl6         7.107          5.384          7.633                     6.608
# Stat4       39.649         73.672         68.138                    60.887
# Il7r       121.156        405.954        376.133                     6.390
# Nur77       39.603         35.059         39.967                   184.248
# Klf4         6.295         14.771         15.286                     4.918
# Coro2a       2.094         11.091         10.912                    10.087
# Ldlr         1.979          0.902          1.646                     0.344
# Ly6c2       42.123        946.471        915.581                  1330.557
# Il18rap      1.337         88.151         96.615                   259.818
#
#            Foxo1-KO-KLRGhi-LCMV-7d  Foxo1-KO-KLRGlo-LCMV-7d  Foxo1-KO-LCMV-0d
# gene_name
# Tcf7                         2.301                   28.946           670.728
# Tbx21                      234.122                  175.334             8.138
# Bcl2                         1.945                    3.001            14.055
# Id2                        167.487                  212.111            24.644
# Id3                          2.210                    3.413           137.718
# Prdm1                       17.239                   15.500             0.387
# Ccl5                     10147.663                 7659.468           244.432
# Klrg1                      502.248                   66.423             0.374
# Bcl6                         2.193                    3.926            12.018
# Stat4                       59.680                   62.541            25.923
# Il7r                         0.800                    2.457            19.185
# Nur77                      165.933                  164.214           343.304
# Klf4                         3.501                    4.010            29.577
# Coro2a                      26.813                   29.994            10.198
# Ldlr                         5.236                    6.302             8.023
# Ly6c2                     1384.999                 1169.391           160.449
# Il18rap                    171.495                  104.533             5.799

# %%
# Now split to overlay WT and KO
wt = subdata[['LCMV-0d', 'KLRGhi-LCMV-7d', 'KLRGlo-LCMV-7d', 
        'KLRGhi-LCMV-12d', 'KLRGlo-LCMV-12d', 'LCMV-35d-rep2']]
ko = subdata[['Foxo1-KO-LCMV-0d', 'Foxo1-KO-KLRGhi-LCMV-7d', 
        'Foxo1-KO-KLRGlo-LCMV-7d', 'Foxo1-KO-KLRGhi-LCMV-12d']]
ko.index = ['Foxo1-KO-' + g for g in ko.index]

sns.set_palette('hls',2)

for gene in wt.index:
    plt.figure()
    ko.loc['Foxo1-KO-' + gene].plot()
    wt.loc[gene].plot()
    plt.title(gene + ': WT vs. KO')
    plt.ylabel('RPKM')
    plt.legend()
    
    plt.xticks(rotation=90)
    
    plt.savefig('figures/KO_vs_WT_{}.png'.format(gene),
            bbox_inches='tight')
